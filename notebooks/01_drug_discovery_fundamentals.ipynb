# %%
print("PharmaGPT v0.2")
# Out:
# PharmaGPT v0.2

# %%
drug_discovery_terms = {
    "Molecule":
        "Chemical compound that may become a drug",

    "Protein":
        "Biological target a drug interacts with",

    "Binding Affinity":
        "Strength of interaction between drug and protein",

    "SMILES":
        "Text representation of molecules",

    "Drug Discovery":
        "Finding molecules that interact with proteins"
}

drug_discovery_terms
# Out:
# {'Molecule': 'Chemical compound that may become a drug',
#  'Protein': 'Biological target a drug interacts with',
#  'Binding Affinity': 'Strength of interaction between drug and protein',
#  'SMILES': 'Text representation of molecules',
#  'Drug Discovery': 'Finding molecules that interact with proteins'}

# %%
smiles_examples = [
    "CCO",
    "CC(=O)OC1=CC=CC=C1C(=O)O",
    "CCN(CC)CCCC(C)NC1=C2C=CC(=CC2=NC=C1)Cl"
]

for s in smiles_examples:
    print(s)
# Out:
# CCO
# CC(=O)OC1=CC=CC=C1C(=O)O
# CCN(CC)CCCC(C)NC1=C2C=CC(=CC2=NC=C1)Cl
